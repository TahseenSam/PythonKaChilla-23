# %% [markdown]
# # Pipelines
# * Pipelines chains together multple steps so that the output of each step is used as input to the next step
#
# * Pipeline makes it easy to apply the same preprocessing to train and test!
# ![image.png](attachment:image.png)
